# %% [markdown]
# <a href="https://colab.research.google.com/github/JagdeepMohanty/VALUE_ADDED_COURSE/blob/main/Task_5(set).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1 = {1, 2, 3, 4}
set2 = set([3, 4, 5, 6])

print("Set1:", set1)
print("Set2:", set2)
# Out:
# Set1: {1, 2, 3, 4}
# Set2: {3, 4, 5, 6}

# %%
s = {1, 2, 3}

s.add(4)
print("After add:", s)

s.remove(2)
print("After remove:", s)

s.discard(10)  # no error if not present
print("After discard:", s)

s.pop()
print("After pop:", s)
# Out:
# After add: {1, 2, 3, 4}
# After remove: {1, 3, 4}
# After discard: {1, 3, 4}
# After pop: {3, 4}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print("Union:", a.union(b))
# OR
print("Union using |:", a | b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Union using |: {1, 2, 3, 4, 5}

# %%
a = {1, 2, 3}
b = {2, 3, 4}

print("Intersection:", a.intersection(b))
# OR
print("Intersection using &:", a & b)
# Out:
# Intersection: {2, 3}
# Intersection using &: {2, 3}

# %%
a = {1, 2, 3}
b = {2, 3, 4}

print("A - B:", a.difference(b))
print("B - A:", b - a)
# Out:
# A - B: {1}
# B - A: {4}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print("Symmetric Difference:", a.symmetric_difference(b))
# OR
print("Using ^:", a ^ b)
# Out:
# Symmetric Difference: {1, 2, 4, 5}
# Using ^: {1, 2, 4, 5}

# %%
a = {1, 2}
b = {1, 2, 3, 4}

print("A is subset of B:", a.issubset(b))
print("B is superset of A:", b.issuperset(a))
# Out:
# A is subset of B: True
# B is superset of A: True

# %%
s = {1, 2, 3}

print(2 in s)
print(5 in s)
# Out:
# True
# False

# %%
lst = [1, 2, 2, 3, 4, 4, 5]

unique = list(set(lst))

print("Original:", lst)
print("Without duplicates:", unique)
# Out:
# Original: [1, 2, 2, 3, 4, 4, 5]
# Without duplicates: [1, 2, 3, 4, 5]

# %%
squares = {x**2 for x in range(1, 6)}
print("Squares:", squares)


evens = {x for x in range(10) if x % 2 == 0}
print("Even numbers:", evens)
# Out:
# Squares: {1, 4, 9, 16, 25}
# Even numbers: {0, 2, 4, 6, 8}

# %%
s = {1, 2, 3}

s.clear()
print("After clear:", s)
# Out:
# After clear: set()
