# %% [markdown]
# <a href="https://colab.research.google.com/github/JagdeepMohanty/VALUE_ADDED_COURSE/blob/main/Jagdeep_Mohanty_DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practice Session day@4

# %%
print("RU")
# Out:
# RU

# %%
a = 10
print (type (a))
b = 10.13
print (type (b))
c = 3 + 2j
print (type (c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
print(1+2)
print(2*3)
print(3/9)
print(3-1)
print(3//10) #floor division
print(3%10)
print(2**3)
# Out:
# 3
# 6
# 0.3333333333333333
# 2
# 0
# 3
# 8

# %%
a = 57
print("the number is ", a )
# Out:
# the number is  57

# %%
a = int(input ("Enter number A is "))
b = int(input ("Enter number B is "))
print ("the number A is ", a, ",the number B is ", b, "and thier addition is ",a+b )
# Out:
# Enter number A is 16
# Enter number B is 24
# the number A is  16 ,the number B is  24 and thier addition is  40

# %%
language = 'Python'
first_letter = language [0]
print(first_letter)

second_letter = language[1]
print(second_letter)

last_index = len(language) - 1
last_letter = language [last_index]
print(last_letter)
# Out:
# P
# y
# n

# %%
language = 'python'
print (language[4:])
print (language[2:4])
print (language[2:])
print (language[1:4])
print (language[0:6:2])
# Out:
# on
# th
# thon
# yth
# pto

# %%
language = "Rai University"
print (language[:4])  #Rai
print (language[:5])  #Rai U
print (language[4:])  #University
print (language[10:13])  #sit
print (language[4:11])   #Univers
print (language[6:10])  #iver
# Out:
# Rai
# Rai U
# University
# sit
# Univers
# iver

# %%
language = "Rai University"
print (language[-14:-10])  #Rai
print (language[-14:-9])  #Rai U
print (language[-10:])  #University
print (language[-4:-1])  #sit
print (language[-10:-3]) #Univers
print (language[-8:-4])  #iver
# Out:
# Rai
# Rai U
# University
# sit
# Univers
# iver

# %%
s = "one 👉 two 👉 three"

print(s.partition("👉"))

print(s.split())

print(s.split("👉"))

print(";".join(s.split("👉")))
# Out:
# ('one ', '👉', ' two 👉 three')
# ['one', '👉', 'two', '👉', 'three']
# ['one ', ' two ', ' three']
# one ; two ; three
